# %%
from PreCurve import picky,clear,smooth
from curve import curveread
from peaks import peakfinder,peakindex,abd_calculator

# %%
curve = curveread ('continuous','infile.txt')

# %%
print(curve)
# Out:
# [[0.47868089 0.25345005]
#  [0.84416552 0.21974516]
#  [0.24706672 0.186459  ]
#  [0.47762739 0.55703677]
#  [0.02747819 0.54342597]
#  [0.16569779 0.7107266 ]
#  [0.2508992  0.89068054]
#  [0.67674737 0.85442927]
#  [0.37786639 0.16604614]
#  [0.38969481 0.8859702 ]
#  [0.47974418 0.36411373]
#  [0.40372824 0.16998194]
#  [0.86375758 0.38212458]
#  [0.4819124  0.15243405]
#  [0.25342602 0.40687202]
#  [0.40155074 0.70120206]
#  [0.23083163 0.87114031]
#  [0.00501015 0.53646297]
#  [0.55126523 0.96818319]
#  [0.89536198 0.40769264]
#  [0.64543598 0.13456298]
#  [0.61342008 0.65868631]
#  [0.18966665 0.16953725]
#  [0.46641506 0.11066285]
#  [0.50292548 0.16476901]
#  [0.68269414 0.76790078]
#  [0.32058559 0.79161952]
#  [0.5455602  0.36628388]
#  [0.41237524 0.09485523]
#  [0.36517465 0.90859366]
#  [0.57419706 0.02418192]
#  [0.73888038 0.24000283]
#  [0.91739969 0.62014857]
#  [0.52462351 0.34281531]
#  [0.14589879 0.63653788]
#  [0.83818722 0.36291433]
#  [0.53023084 0.04316083]
# ...

# %%
picky(curve)
# Out:
# True

# %%
clear(curve)
# Out:
# array([[-3.08399702e-01,  1.31516389e+00],
#        [ 1.43692250e-01,  3.10508385e-01],
#        [-3.59947020e-02, -7.02669004e-01],
#        [-1.36184562e+00,  7.39542782e-02],
#        [-9.12810402e-02, -1.55726188e+00],
#        [-5.55909877e-01, -4.37266385e-01],
#        [-4.51102293e-01,  1.66764526e+00],
#        [ 2.16141666e-01,  1.32775621e+00],
#        [-1.31331259e-03,  1.86614073e+00],
#        [ 5.40485703e-01,  1.72475675e-01],
#        [ 1.46204366e+00, -1.99982329e+00],
#        [-2.37915403e-01,  6.24416202e-01],
#        [ 2.45431044e+00,  2.23297048e+00],
#        [-5.09128365e-01, -5.88775371e-01],
#        [-4.13992867e-01, -8.16658181e-01],
#        [-1.44490050e+00, -1.42020488e+00],
#        [-5.10166591e-01,  1.06361973e+00],
#        [ 9.70897257e-01,  7.44513179e-02],
#        [-1.00616684e+00, -1.20009170e+00],
#        [-3.13320056e-02, -1.18576353e-01],
#        [-3.11791452e-01,  9.94100101e-02],
#        [-3.76935619e-01,  1.02500973e+00],
# ...

# %%
smooth(curve)
# Out:
# array([[-2.61577358e-02, -1.71908346e-01],
#        [ 4.30913675e-01, -1.19369265e+00],
#        [ 4.56350525e-01, -8.11810929e-01],
#        [-1.70429937e-01,  6.22068462e-01],
#        [ 4.80769253e-01,  3.99861989e-01],
#        [ 1.67338391e+00, -4.41733884e-01],
#        [ 7.12738787e-01, -6.73432551e-02],
#        [-2.37051791e-01,  2.88652807e-01],
#        [-7.26935347e-01,  5.41133026e-01],
#        [ 5.61936913e-01,  1.25976049e+00],
#        [ 1.11958764e+00, -1.36061558e+00],
#        [-6.54665440e-01,  6.08781265e-01],
#        [ 6.62103053e-01,  1.50140566e+00],
#        [-5.05944888e-01, -1.17006765e+00],
#        [-7.79468065e-02,  5.37767178e-01],
#        [ 1.54664050e+00, -2.63835017e-01],
#        [-3.47028578e-01,  7.17150031e-01],
#        [-2.14864152e+00, -6.54236403e-01],
#        [-1.32148291e+00, -7.43251729e-01],
#        [ 1.06806254e-01,  6.26411917e-01],
#        [-1.09578488e+00,  7.05469592e-01],
#        [ 9.28950910e-01,  2.60022950e+00],
# ...

# %%
theta_peaks = peakfinder(curve)

# %%
wavelength = 1.5 # nm

# %%
element = 'cu'

# %%
peakindex(theta_peaks, wavelength, element)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-44c75f19ccbf> in <module>
# ----> 1 peakindex(theta_peaks, wavelength, element)
#
# ~/local doc/metal_oxidation_md_simulater/functions/peaks.py in peakindex(theta_peaks, wavelength, element)
#      20 def abd_calculator(theta_peaks, wavelength, index):
#      21     """
# ---> 22     This function is to calculat the real lattice parameter from the experiments.
#      23     """
#      24     return a,b,c
#
# NameError: name 'np' is not defined

# %%
help(peakfinder)
# Out:
# Help on function peakfinder in module peaks:
#
# peakfinder(curve)
#     This function is to find the positions of peaks in a curve.
#     I will set a minmum value for peak intensity, which means that this function may ignore some small peaks.
#     I will work on some make-ups.

# %%
# !pdoc3 --force --html --output-dir ./docs curve.py
# Out:
# ./docs/curve.html
